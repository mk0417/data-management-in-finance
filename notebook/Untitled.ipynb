# %% [markdown]
# # lntrodution to Python
# - import data
# - output data

# %% [markdown]
# ### Import data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Make working directory

# %%
wd = '/users/ml/dropbox/teaching/data/'

# %%
wd
# Out:
# '/users/ml/dropbox/teaching/data/'

# %%
crsp = pd.read_csv(wd+'crsp_monthly.txt',sep='\t',low_memory=False)

# %%
crsp[10:20]
# Out:
#     permno      date  shrcd  exchcd siccd    ncusip ticker  \
# 10   10000  19861128   10.0     3.0  3990  68391610  OMFGA
# 11   10000  19861231   10.0     3.0  3990  68391610  OMFGA
# 12   10000  19870130   10.0     3.0  3990  68391610  OMFGA
# 13   10000  19870227   10.0     3.0  3990  68391610  OMFGA
# 14   10000  19870331   10.0     3.0  3990  68391610  OMFGA
# 15   10000  19870430   10.0     3.0  3990  68391610  OMFGA
# 16   10000  19870529   10.0     3.0  3990  68391610  OMFGA
# 17   10000  19870630   10.0     3.0  3990  68391610  OMFGA
# 18   10001  19860131   11.0     3.0  4920  39040610   GFGC
# 19   10001  19860228   11.0     3.0  4920  39040610   GFGC
#
#                        comnam     cusip      prc     vol       ret  shrout  \
# 10  OPTIMUM MANUFACTURING INC  68391610 -0.82813  2113.0  0.060000  3843.0
# 11  OPTIMUM MANUFACTURING INC  68391610 -0.51563  3215.0 -0.377358  3843.0
# 12  OPTIMUM MANUFACTURING INC  68391610 -0.40625  1754.0 -0.212121  3893.0
# ...
