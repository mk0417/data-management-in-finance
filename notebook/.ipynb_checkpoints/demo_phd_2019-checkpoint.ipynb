# %% [markdown]
# # Python demo

# %% [markdown]
# ## Import required packages

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Navigate to working directory

# %%
wd = '/Users/ml/Dropbox/teaching/data/'
os.chdir(wd)

# %% [markdown]
# ## Import and output data
# You can import and output various data formats by using Pandas:
# - CSV files (.csv)
# - Excel files (.xlsx)
# - Parquet (.parquet)
# - SAS files (.sas7bdat)
# - Stata files (.dta)
# - TEXT files (.txt)
#
# ...

# %% [markdown]
# ### Bash command: list files in a folder
# `ls` and `grep`
#
# For example, I want to import CRSP monthly stock files, but I am not sure the name of the dataset.

# %%
# !ls ./ | grep crsp
# Out:
# crsp_monthly.dta
# crsp_monthly.txt
# crsp_raw_data.txt
# merge_crsp.txt

# %% [markdown]
# ### Import .txt file

# %%
crsp = pd.read_csv('./crsp_raw_data.txt',sep='\t')
